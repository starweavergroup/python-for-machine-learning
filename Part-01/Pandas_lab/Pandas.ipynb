# %% [markdown]
# ### Pandas deep_dive Lab

# %% [markdown]
# 1. DataFrames
# 2. Series

# %% [markdown]
# Data
#
# 1. Students
# 2. Classes
# 3. Students_Classes

# %%
import pandas as pd

# %%
df_students = pd.read_csv('students.csv')

# %%
type(df_students)
# Out:
# pandas.core.frame.DataFrame

# %%
df_classes = pd.read_csv('classes.csv')

# %%
df_stud_class = pd.read_csv('students_classes.csv')

# %%
type(df_students)
# Out:
# pandas.core.frame.DataFrame

# %%
df_students
# Out:
#    Student_Id First_Name Last_Name                       Street_Name  \
# 0         100       John       Doe                 120 jefferson st.
# 1         101       Jack  McGinnis                      220 hobo Av.
# 2         102      John     Repici                 120 Jefferson St.
# 3         103    Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4         104        Ron  Blankman                               NaN
# 5         105      Joan        Jet               9th, at Terrace plc
# 6         106      Robin      Wood                        4, 4th Ave
# 7         107       Will       NaN                           Medina
# 8         108       Jeff     Bezos                           5th Ave
#
#           City State    Zip  CGPA
# 0    Riverside    NJ   8075   3.8
# 1        Phila    PA   9119   3.7
# 2    Riverside    NJ   8075   2.9
# 3     SomeTown    SD  91234   4.0
# 4     SomeTown    SD    298   2.3
# 5  Desert City    CO    123   4.2
# ...

# %%
df_students
# Out:
#    Student_Id First_Name Last_Name                       Street_Name  \
# 0         100       John       Doe                 120 jefferson st.
# 1         101       Jack  McGinnis                      220 hobo Av.
# 2         102      John     Repici                 120 Jefferson St.
# 3         103    Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4         104        Ron  Blankman                               NaN
# 5         105      Joan        Jet               9th, at Terrace plc
# 6         106      Robin      Wood                        4, 4th Ave
# 7         107       Will       NaN                           Medina
# 8         108       Jeff     Bezos                           5th Ave
#
#           City State    Zip  CGPA
# 0    Riverside    NJ   8075   3.8
# 1        Phila    PA   9119   3.7
# 2    Riverside    NJ   8075   2.9
# 3     SomeTown    SD  91234   4.0
# 4     SomeTown    SD    298   2.3
# 5  Desert City    CO    123   4.2
# ...

# %%
df_classes
# Out:
#    Class_Id  Class_code                   Class_Name  Credits
# 0         1        2340      Python for Data Science        3
# 1         2        2341  R for  Statistical Analysis        3
# 2         3        2350         Machine Learning 101        5
# 3         4        2567                Deep Learning        5
# 4         5        3450            Self Driving Cars        5

# %%
df_stud_class
# Out:
#    Student_Id  Class_Id
# 0         100         1
# 1         100         2
# 2         101         3
# 3         103         4
# 4         106         5
# 5         106         4
# 6         104         3
# 7         105         1
# 8         105         4
# 9         104         2

# %%
df_students.describe(df_students["CGPA"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-3b9677c34e4f> in <module>
# ----> 1 df_students.describe(df_students["CGPA"])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   10183
#   10184             # get them all to be in [0, 1]
# > 10185             self._check_percentile(percentiles)
#   10186
#   10187             # median should always be included
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _check_percentile(self, q)
#   10299         else:
#   10300             if not all(0 <= qs <= 1 for qs in q):
# > 10301                 raise ValueError(msg.format(q / 100.0))
#   10302         return q
#   10303
#
# ValueError: percentiles should all be in the interval [0, 1]. Try [0.038 0.037 0.029 0.04  0.023 0.042 0.04  0.038 0.038] instead.

# %%
df_city = df_students.City

# %%
type(df_city)
# Out:
# pandas.core.series.Series

# %%
df_city
# Out:
# 0      Riverside
# 1          Phila
# 2      Riverside
# 3       SomeTown
# 4       SomeTown
# 5    Desert City
# 6        Seattle
# 7        Seattle
# 8       Bellevue
# Name: City, dtype: object

# %%
df_cgpa_high = df_students[df_students.CGPA >= 3.0]

# %%
type(df_cgpa_high)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cgpa_high
# Out:
#    Student_Id First_Name Last_Name                       Street_Name  \
# 0         100       John       Doe                 120 jefferson st.
# 1         101       Jack  McGinnis                      220 hobo Av.
# 3         103    Stephen     Tyler  7452 Terrace "At the Plaza" road
# 5         105      Joan        Jet               9th, at Terrace plc
# 6         106      Robin      Wood                        4, 4th Ave
# 7         107       Will       NaN                           Medina
# 8         108       Jeff     Bezos                           5th Ave
#
#           City State    Zip  CGPA
# 0    Riverside    NJ   8075   3.8
# 1        Phila    PA   9119   3.7
# 3     SomeTown    SD  91234   4.0
# 5  Desert City    CO    123   4.2
# 6      Seattle    WA  98001   4.0
# 7      Seattle    WA  98111   3.8
# 8     Bellevue    WA  98007   3.8

# %%
type(df_cgpa_high)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cgpa_high.CGPA.min()
# Out:
# 3.7

# %%
df_cgpa_low= df_students.loc[df_students["CGPA"]<3.0]

# %%
df_cgpa_low
# Out:
#    Student_Id First_Name Last_Name        Street_Name       City State   Zip  \
# 2         102      John     Repici  120 Jefferson St.  Riverside    NJ  8075
# 4         104        Ron  Blankman                NaN   SomeTown    SD   298
#
#    CGPA
# 2   2.9
# 4   2.3

# %%
df_students.CGPA.max()
# Out:
# 4.2

# %%
df_max_cgpa_students = df_students[df_students.CGPA == df_students.CGPA.max()]

# %%
df_max_cgpa_students
# Out:
#    Student_Id First_Name Last_Name          Street_Name         City State  \
# 5         105      Joan        Jet  9th, at Terrace plc  Desert City    CO
#
#    Zip  CGPA
# 5  123   4.2

# %%
df_students[df_students.CGPA == df_students.CGPA.max()]
# Out:
#    Student_Id First_Name Last_Name          Street_Name         City State  \
# 5         105      Joan        Jet  9th, at Terrace plc  Desert City    CO
#
#    Zip  CGPA
# 5  123   4.2

# %%
df_students[df_students.CGPA == df_students.CGPA.min()]
# Out:
#    Student_Id First_Name Last_Name Street_Name      City State  Zip  CGPA
# 4         104        Ron  Blankman         NaN  SomeTown    SD  298   2.3

# %%
df_students.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df_students[df_students.index==6]
# Out:
#       City  Student_Id First_Name Last_Name Street_Name State    Zip  CGPA
# 6  Seattle         106      Robin      Wood  4, 4th Ave    WA  98001   4.0

# %%
df_students
# Out:
#    Student_Id First_Name Last_Name                       Street_Name  \
# 0         100       John       Doe                 120 jefferson st.
# 1         101       Jack  McGinnis                      220 hobo Av.
# 2         102      John     Repici                 120 Jefferson St.
# 3         103    Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4         104        Ron  Blankman                               NaN
# 5         105      Joan        Jet               9th, at Terrace plc
# 6         106      Robin      Wood                        4, 4th Ave
# 7         107       Will       NaN                           Medina
# 8         108       Jeff     Bezos                           5th Ave
#
#           City State    Zip  CGPA
# 0    Riverside    NJ   8075   3.8
# 1        Phila    PA   9119   3.7
# 2    Riverside    NJ   8075   2.9
# 3     SomeTown    SD  91234   4.0
# 4     SomeTown    SD    298   2.3
# 5  Desert City    CO    123   4.2
# ...

# %%
df_students.index  = df_students.City

# %%
df_students
# Out:
#              Student_Id First_Name Last_Name  \
# City
# Riverside           100       John       Doe
# Phila               101       Jack  McGinnis
# Riverside           102      John     Repici
# SomeTown            103    Stephen     Tyler
# SomeTown            104        Ron  Blankman
# Desert City         105      Joan        Jet
# Seattle             106      Robin      Wood
# Seattle             107       Will       NaN
# Bellevue            108       Jeff     Bezos
#
#                                   Street_Name         City State    Zip  CGPA
# City
# Riverside                   120 jefferson st.    Riverside    NJ   8075   3.8
# Phila                            220 hobo Av.        Phila    PA   9119   3.7
# Riverside                   120 Jefferson St.    Riverside    NJ   8075   2.9
# SomeTown     7452 Terrace "At the Plaza" road     SomeTown    SD  91234   4.0
# SomeTown                                  NaN     SomeTown    SD    298   2.3
# ...

# %%
df_students[df_students.index=='Seattle']
# Out:
#          Student_Id First_Name Last_Name Street_Name     City State    Zip  \
# City
# Seattle         106      Robin      Wood  4, 4th Ave  Seattle    WA  98001
# Seattle         107       Will       NaN     Medina   Seattle    WA  98111
#
#          CGPA
# City
# Seattle   4.0
# Seattle   3.8

# %%
df_students = df_students.drop(columns = ['City'])

# %%
df_students
# Out:
#              Student_Id First_Name Last_Name  \
# City
# Riverside           100       John       Doe
# Phila               101       Jack  McGinnis
# Riverside           102      John     Repici
# SomeTown            103    Stephen     Tyler
# SomeTown            104        Ron  Blankman
# Desert City         105      Joan        Jet
# Seattle             106      Robin      Wood
# Seattle             107       Will       NaN
# Bellevue            108       Jeff     Bezos
#
#                                   Street_Name State    Zip  CGPA
# City
# Riverside                   120 jefferson st.    NJ   8075   3.8
# Phila                            220 hobo Av.    PA   9119   3.7
# Riverside                   120 Jefferson St.    NJ   8075   2.9
# SomeTown     7452 Terrace "At the Plaza" road    SD  91234   4.0
# SomeTown                                  NaN    SD    298   2.3
# Desert City               9th, at Terrace plc    CO    123   4.2
# ...

# %%
df_students = df_students.reset_index()

# %%
df_students
# Out:
#           City  Student_Id First_Name Last_Name  \
# 0    Riverside         100       John       Doe
# 1        Phila         101       Jack  McGinnis
# 2    Riverside         102      John     Repici
# 3     SomeTown         103    Stephen     Tyler
# 4     SomeTown         104        Ron  Blankman
# 5  Desert City         105      Joan        Jet
# 6      Seattle         106      Robin      Wood
# 7      Seattle         107       Will       NaN
# 8     Bellevue         108       Jeff     Bezos
#
#                         Street_Name State    Zip  CGPA
# 0                 120 jefferson st.    NJ   8075   3.8
# 1                      220 hobo Av.    PA   9119   3.7
# 2                 120 Jefferson St.    NJ   8075   2.9
# 3  7452 Terrace "At the Plaza" road    SD  91234   4.0
# 4                               NaN    SD    298   2.3
# 5               9th, at Terrace plc    CO    123   4.2
# 6                        4, 4th Ave    WA  98001   4.0
# ...

# %%
df_students.iloc[5]
# Out:
# City                   Desert City
# Student_Id                     105
# First_Name                   Joan
# Last_Name                      Jet
# Street_Name    9th, at Terrace plc
# State                           CO
# Zip                            123
# CGPA                           4.2
# Name: 5, dtype: object

# %%
df_students.CGPA.std()
# Out:
# 0.6112373606964083

# %%
df_students.CGPA.max()
# Out:
# 4.2

# %%
df_students.CGPA.min()
# Out:
# 2.3

# %%
df_students.CGPA.mean()
# Out:
# 3.611111111111111

# %%
df_students['mean_CGPA'] = df_students.CGPA.mean()

# %%
df_students
# Out:
#           City  Student_Id First_Name Last_Name  \
# 0    Riverside         100       John       Doe
# 1        Phila         101       Jack  McGinnis
# 2    Riverside         102      John     Repici
# 3     SomeTown         103    Stephen     Tyler
# 4     SomeTown         104        Ron  Blankman
# 5  Desert City         105      Joan        Jet
# 6      Seattle         106      Robin      Wood
# 7      Seattle         107       Will       NaN
# 8     Bellevue         108       Jeff     Bezos
#
#                         Street_Name State    Zip  CGPA  mean_CGPA
# 0                 120 jefferson st.    NJ   8075   3.8   3.611111
# 1                      220 hobo Av.    PA   9119   3.7   3.611111
# 2                 120 Jefferson St.    NJ   8075   2.9   3.611111
# 3  7452 Terrace "At the Plaza" road    SD  91234   4.0   3.611111
# 4                               NaN    SD    298   2.3   3.611111
# 5               9th, at Terrace plc    CO    123   4.2   3.611111
# ...

# %%
df_students = df_students.reset_index()

# %%
type(city_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_students.groupby(['City']).size()
# Out:
# City
# Bellevue       1
# Desert City    1
# Phila          1
# Riverside      2
# Seattle        2
# SomeTown       2
# dtype: int64

# %%
city_groups = df_students.groupby(['City'])

# %%
city_groups.describe()
# Out:
#             Student_Id                                                        \
#                  count   mean       std    min     25%    50%     75%    max
# City
# Bellevue           1.0  108.0       NaN  108.0  108.00  108.0  108.00  108.0
# Desert City        1.0  105.0       NaN  105.0  105.00  105.0  105.00  105.0
# Phila              1.0  101.0       NaN  101.0  101.00  101.0  101.00  101.0
# Riverside          2.0  101.0  1.414214  100.0  100.50  101.0  101.50  102.0
# Seattle            2.0  106.5  0.707107  106.0  106.25  106.5  106.75  107.0
# SomeTown           2.0  103.5  0.707107  103.0  103.25  103.5  103.75  104.0
#
#               Zip           ...   CGPA      mean_CGPA                 \
#             count     mean  ...    75%  max     count      mean  std
# City                        ...
# Bellevue      1.0  98007.0  ...  3.800  3.8       1.0  3.611111  NaN
# Desert City   1.0    123.0  ...  4.200  4.2       1.0  3.611111  NaN
# ...

# %%
city_groups.get_group('Seattle')['CGPA'].mean()
# Out:
# 3.9

# %%
df_students['City'].unique()
# Out:
# array(['Riverside', 'Phila', 'SomeTown', 'Desert City', 'Seattle',
#        'Bellevue'], dtype=object)

# %% [markdown]
# ### Merging DataFrames

# %%
df_students
# Out:
#           City  Student_Id First_Name Last_Name  \
# 0    Riverside         100       John       Doe
# 1        Phila         101       Jack  McGinnis
# 2    Riverside         102      John     Repici
# 3     SomeTown         103    Stephen     Tyler
# 4     SomeTown         104        Ron  Blankman
# 5  Desert City         105      Joan        Jet
# 6      Seattle         106      Robin      Wood
# 7      Seattle         107       Will       NaN
# 8     Bellevue         108       Jeff     Bezos
#
#                         Street_Name State    Zip  CGPA  mean_CGPA
# 0                 120 jefferson st.    NJ   8075   3.8   3.611111
# 1                      220 hobo Av.    PA   9119   3.7   3.611111
# 2                 120 Jefferson St.    NJ   8075   2.9   3.611111
# 3  7452 Terrace "At the Plaza" road    SD  91234   4.0   3.611111
# 4                               NaN    SD    298   2.3   3.611111
# 5               9th, at Terrace plc    CO    123   4.2   3.611111
# ...

# %%
df_stud_class
# Out:
#    Student_Id  Class_Id
# 0         100         1
# 1         100         2
# 2         101         3
# 3         103         4
# 4         106         5
# 5         106         4
# 6         104         3
# 7         105         1
# 8         105         4
# 9         104         2

# %%
df1= pd.merge(df_students,df_stud_class,on='Student_Id')

# %%
df1
# Out:
#           City  Student_Id First_Name Last_Name  \
# 0    Riverside         100       John       Doe
# 1    Riverside         100       John       Doe
# 2        Phila         101       Jack  McGinnis
# 3     SomeTown         103    Stephen     Tyler
# 4     SomeTown         104        Ron  Blankman
# 5     SomeTown         104        Ron  Blankman
# 6  Desert City         105      Joan        Jet
# 7  Desert City         105      Joan        Jet
# 8      Seattle         106      Robin      Wood
# 9      Seattle         106      Robin      Wood
#
#                         Street_Name State    Zip  CGPA  mean_CGPA  Class_Id
# 0                 120 jefferson st.    NJ   8075   3.8   3.611111         1
# 1                 120 jefferson st.    NJ   8075   3.8   3.611111         2
# 2                      220 hobo Av.    PA   9119   3.7   3.611111         3
# 3  7452 Terrace "At the Plaza" road    SD  91234   4.0   3.611111         4
# ...

# %%
# Check out pd.concat , pd.join

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_students
# Out:
#           City  Student_Id First_Name Last_Name  \
# 0    Riverside         100       John       Doe
# 1        Phila         101       Jack  McGinnis
# 2    Riverside         102      John     Repici
# 3     SomeTown         103    Stephen     Tyler
# 4     SomeTown         104        Ron  Blankman
# 5  Desert City         105      Joan        Jet
# 6      Seattle         106      Robin      Wood
# 7      Seattle         107       Will       NaN
# 8     Bellevue         108       Jeff     Bezos
#
#                         Street_Name State    Zip  CGPA  mean_CGPA
# 0                 120 jefferson st.    NJ   8075   3.8   3.611111
# 1                      220 hobo Av.    PA   9119   3.7   3.611111
# 2                 120 Jefferson St.    NJ   8075   2.9   3.611111
# 3  7452 Terrace "At the Plaza" road    SD  91234   4.0   3.611111
# 4                               NaN    SD    298   2.3   3.611111
# 5               9th, at Terrace plc    CO    123   4.2   3.611111
# ...

# %%
# read from json file

# %%
df_quiz = pd.read_json('quiz.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5d4fd64fba6> in <module>
# ----> 1 df_quiz = pd.read_json('quiz.json')
#
# NameError: name 'pd' is not defined
