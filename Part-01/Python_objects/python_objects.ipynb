# %% [markdown]
# ### List

# %%
mylist = [10,20,30,40,50]

# %%
type(mylist)
# Out:
# list

# %%
len(mylist)
# Out:
# 5

# %%
mylist[0]
# Out:
# 10

# %%
mylist[4]
# Out:
# 50

# %%
mylist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-30998d85754d> in <module>()
# ----> 1 mylist[5]
#
# IndexError: list index out of range

# %%
mycitylist = ['Seattle','Houston','New York','Chicago']

# %%
mycitylist
# Out:
# ['Seattle', 'Houston', 'New York', 'Chicago']

# %%
type(mycitylist)
# Out:
# list

# %%
mycitylist.append('San Francisco')

# %%
mycitylist
# Out:
# ['Seattle', 'Houston', 'New York', 'Chicago', 'San Francisco']

# %%
mycitylist.pop()
# Out:
# 'Tacoma'

# %%
mycitylist
# Out:
# ['Seattle', 'Bellevue', 'Renton', 'Redmond']

# %%
mycitylist.pop(1)
# Out:
# 'Bellevue'

# %%
mycitylist
# Out:
# ['Seattle', 'Renton', 'Redmond']

# %% [markdown]
# ### Tuple

# %%
list1 = [10,20,30,40,50]

# %%
mytuple = tuple(list1)

# %%
mytuple
# Out:
# (10, 20, 30, 35, 50, 60)

# %%
type(mytuple)
# Out:
# tuple

# %%
mytuple.append(70)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-e85366763d8f> in <module>()
# ----> 1 mytuple.append(70)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mytuple[4] = 65
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-a3f684c041ce> in <module>()
# ----> 1 mytuple[4] = 65
#
# TypeError: 'tuple' object does not support item assignment

# %%
mynewlitfromtuple = list(mytuple)

# %%
mynewlitfromtuple
# Out:
# [10, 20, 30, 35, 50, 60]

# %% [markdown]
# ### Set

# %%
list1 = [10,10,10,20,20,30,30,40]

# %%
myset = set(list1)

# %%
mytuple = (10,20,20)

# %%
type(mytuple)
# Out:
# tuple

# %%
list1 = [10,10,10,20,20,30,30,40]

# %%
myset = set(list1)

# %%
type(myset)
# Out:
# set

# %%
myset
# Out:
# {10, 20, 30, 40}

# %% [markdown]
# ### Dictionaries

# %%
mydict = {}

# %%
type(mydict)
# Out:
# dict

# %%
mydict[100] = 'Praba'

# %%
mydict
# Out:
# {100: 'Praba'}

# %%
mydict[101] = 'John'

# %%
mydict
# Out:
# {100: 'Praba', 101: 'John'}

# %%
mydict[102] = 'Lisa'

# %%
mydict
# Out:
# {100: 'Praba', 101: 'John', 102: 'Lisa'}

# %%
mydict[102]
# Out:
# 'Lisa'

# %%
for k,v in mydict.items():
    print(k,v)
# Out:
# 100 Praba
# 101 John
# 102 Lisa

# %%
for k in mydict.keys():
    print(k)
# Out:
# 100
# 101
# 102

# %%
mydict[102] = 'Sally'

# %%
mydict
# Out:
# {100: 'Praba', 101: 'John', 102: 'Sally'}

# %%
list1 = ['Praba','Seattle']

# %%
mydict[104] = list1

# %%
mydict
# Out:
# {100: 'Praba', 101: 'John', 102: 'Sally', 104: ['Praba', 'Seattle']}

# %%
mydict[104]
# Out:
# ['Praba', 'Seattle']

# %%
mydict[104][1]
# Out:
# 'Seattle'
